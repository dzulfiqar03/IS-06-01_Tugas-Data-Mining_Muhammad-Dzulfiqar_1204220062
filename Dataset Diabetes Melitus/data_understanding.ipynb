# %%
import pandas as pd
import import_ipynb
from manipulate_data import show_data, print_data
# Out:
#      Gender  Age              Diagnose  Hemoglobin  Hematokrit  Lekosit  \
# 0         L    1             DM TYPE 2        12.6        37.1     7130
# 1         P    1  DM TYPE 2 + Penyerta        11.3        33.6    13730
# 2         P    1  DM TYPE 2 + Penyerta        13.3        39.5     8330
# 3         P    1  DM TYPE 2 + Penyerta        14.2        41.6    15680
# 4         L    1             DM TYPE 2        12.1        36.2    20590
# ...     ...  ...                   ...         ...         ...      ...
# 1018      P   84             DM TYPE 2        14.4        42.5     7840
# 1019      P   84  DM TYPE 2 + Penyerta        11.2        33.3    24030
# 1020      L   84  DM TYPE 2 + Penyerta        12.4        37.2     5510
# 1021      P   86             DM TYPE 2        11.7        33.5     4710
# 1022      P   86  DM TYPE 2 + Penyerta         9.0        26.0     6660
#
#       Eritrosit  Trombosit  HbA1c  RBG
# 0          4.09     241000   10.6  150
# ...

# %% [markdown]
# AMBIL DATA

# %%
path = 'Dataset.xlsx'
df = show_data(path)
# Out:
#      Gender  Age              Diagnose  Hemoglobin  Hematokrit  Lekosit  \
# 0         L    1             DM TYPE 2        12.6        37.1     7130
# 1         P    1  DM TYPE 2 + Penyerta        11.3        33.6    13730
# 2         P    1  DM TYPE 2 + Penyerta        13.3        39.5     8330
# 3         P    1  DM TYPE 2 + Penyerta        14.2        41.6    15680
# 4         L    1             DM TYPE 2        12.1        36.2    20590
# ...     ...  ...                   ...         ...         ...      ...
# 1018      P   84             DM TYPE 2        14.4        42.5     7840
# 1019      P   84  DM TYPE 2 + Penyerta        11.2        33.3    24030
# 1020      L   84  DM TYPE 2 + Penyerta        12.4        37.2     5510
# 1021      P   86             DM TYPE 2        11.7        33.5     4710
# 1022      P   86  DM TYPE 2 + Penyerta         9.0        26.0     6660
#
#       Eritrosit  Trombosit  HbA1c  RBG
# 0          4.09     241000   10.6  150
# ...

# %% [markdown]
# CEK DATA DESKRIPTIF

# %%
def deskripsi_data():
    df = show_data(path)
    deskripsi = df.describe().round(0)
    print(deskripsi)
    return deskripsi

deskripsi_data()
# Out:
#      Gender  Age              Diagnose  Hemoglobin  Hematokrit  Lekosit  \
# 0         L    1             DM TYPE 2        12.6        37.1     7130
# 1         P    1  DM TYPE 2 + Penyerta        11.3        33.6    13730
# 2         P    1  DM TYPE 2 + Penyerta        13.3        39.5     8330
# 3         P    1  DM TYPE 2 + Penyerta        14.2        41.6    15680
# 4         L    1             DM TYPE 2        12.1        36.2    20590
# ...     ...  ...                   ...         ...         ...      ...
# 1018      P   84             DM TYPE 2        14.4        42.5     7840
# 1019      P   84  DM TYPE 2 + Penyerta        11.2        33.3    24030
# 1020      L   84  DM TYPE 2 + Penyerta        12.4        37.2     5510
# 1021      P   86             DM TYPE 2        11.7        33.5     4710
# 1022      P   86  DM TYPE 2 + Penyerta         9.0        26.0     6660
#
#       Eritrosit  Trombosit  HbA1c  RBG
# 0          4.09     241000   10.6  150
# ...

# %% [markdown]
# CEK INFORMASI DATA (TIPE DATA)

# %%
info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      1023 non-null   object
#  1   Age         1023 non-null   int64
#  2   Diagnose    1023 non-null   object
#  3   Hemoglobin  1023 non-null   float64
#  4   Hematokrit  1023 non-null   float64
#  5   Lekosit     1023 non-null   int64
#  6   Eritrosit   1023 non-null   float64
#  7   Trombosit   1023 non-null   int64
#  8   HbA1c       1023 non-null   float64
#  9   RBG         1023 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 80.1+ KB

# %%
shape = df.shape
print(shape)
# Out:
# (1023, 10)

# %%
corr = df.corr(numeric_only=True)

print(corr)
# Out:
#                  Age  Hemoglobin  Hematokrit   Lekosit  Eritrosit  Trombosit  \
# Age         1.000000   -0.139416   -0.118936 -0.044087  -0.165441  -0.019036
# Hemoglobin -0.139416    1.000000    0.978132 -0.019806   0.843207  -0.215565
# Hematokrit -0.118936    0.978132    1.000000 -0.022269   0.884326  -0.195306
# Lekosit    -0.044087   -0.019806   -0.022269  1.000000  -0.019606   0.141848
# Eritrosit  -0.165441    0.843207    0.884326 -0.019606   1.000000  -0.132649
# Trombosit  -0.019036   -0.215565   -0.195306  0.141848  -0.132649   1.000000
# HbA1c      -0.123282    0.148211    0.131320  0.002256   0.133614  -0.003020
# RBG        -0.134580    0.120546    0.103056  0.156713   0.097328   0.016027
#
#                HbA1c       RBG
# Age        -0.123282 -0.134580
# Hemoglobin  0.148211  0.120546
# Hematokrit  0.131320  0.103056
# Lekosit     0.002256  0.156713
# Eritrosit   0.133614  0.097328
# Trombosit  -0.003020  0.016027
# HbA1c       1.000000  0.251934
# ...

# %% [markdown]
# CEK DATA NULL

# %%
def isNull():
    isNull = df.isnull().sum()
    return isNull

print(isNull())
print(df.isnull())
# Out:
# Gender        0
# Age           0
# Diagnose      0
# Hemoglobin    0
# Hematokrit    0
# Lekosit       0
# Eritrosit     0
# Trombosit     0
# HbA1c         0
# RBG           0
# dtype: int64
#       Gender    Age  Diagnose  Hemoglobin  Hematokrit  Lekosit  Eritrosit  \
# 0      False  False     False       False       False    False      False
# 1      False  False     False       False       False    False      False
# 2      False  False     False       False       False    False      False
# 3      False  False     False       False       False    False      False
# 4      False  False     False       False       False    False      False
# ...      ...    ...       ...         ...         ...      ...        ...
# 1018   False  False     False       False       False    False      False
# 1019   False  False     False       False       False    False      False
# 1020   False  False     False       False       False    False      False
# ...

# %%
def duplicate_check():
    duplicate = df.duplicated().sum()
    return duplicate

print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1018    False
# 1019    False
# 1020    False
# 1021    False
# 1022    False
# Length: 1023, dtype: bool

# %% [markdown]
# AKSIKAN DATA UNDERSTANDING

# %%
def understanding():
    df = show_data(path)
    deskripsi = deskripsi_data()
    isnull_df = isNull()
    print(info)
    print(shape)
    print(corr)
    return deskripsi, isnull_df, df

understanding()
# Out:
#      Gender  Age              Diagnose  Hemoglobin  Hematokrit  Lekosit  \
# 0         L    1             DM TYPE 2        12.6        37.1     7130
# 1         P    1  DM TYPE 2 + Penyerta        11.3        33.6    13730
# 2         P    1  DM TYPE 2 + Penyerta        13.3        39.5     8330
# 3         P    1  DM TYPE 2 + Penyerta        14.2        41.6    15680
# 4         L    1             DM TYPE 2        12.1        36.2    20590
# ...     ...  ...                   ...         ...         ...      ...
# 1018      P   84             DM TYPE 2        14.4        42.5     7840
# 1019      P   84  DM TYPE 2 + Penyerta        11.2        33.3    24030
# 1020      L   84  DM TYPE 2 + Penyerta        12.4        37.2     5510
# 1021      P   86             DM TYPE 2        11.7        33.5     4710
# 1022      P   86  DM TYPE 2 + Penyerta         9.0        26.0     6660
#
#       Eritrosit  Trombosit  HbA1c  RBG
# 0          4.09     241000   10.6  150
# ...
